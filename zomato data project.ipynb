# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\USER\\OneDrive\\weekly task'

# %%
df = pd.read_csv("Zomato-data-.csv")
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
df.describe()
# Out:
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# 25%       6.750000                   200.000000
# 50%      43.500000                   400.000000
# 75%     221.750000                   600.000000
# max    4884.000000                   950.000000

# %%
df["listed_in(type)"].value_counts()
# Out:
# listed_in(type)
# Dining    110
# Cafes      23
# other       8
# Buffet      7
# Name: count, dtype: int64

# %%
df["votes"].max()
# Out:
# 4884

# %%
df[df["votes"] == df["votes"].max()]
# Out:
#                  name online_order book_table   rate  votes  \
# 38  Empire Restaurant          Yes         No  4.4/5   4884
#
#     approx_cost(for two people) listed_in(type)
# 38                          750           other

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_cost(for two people)', 'listed_in(type)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
df["approx_cost(for two people)"].value_counts()
# Out:
# approx_cost(for two people)
# 300    23
# 200    16
# 150    16
# 400    15
# 500    14
# 600    13
# 800    12
# 100     6
# 450     6
# 250     6
# 700     5
# 550     3
# 750     3
# 350     3
# 900     2
# 850     2
# 650     2
# 950     1
# Name: count, dtype: int64

# %%
df["online_order"].value_counts()
# Out:
# online_order
# No     90
# Yes    58
# Name: count, dtype: int64

# %%
df["book_table"].value_counts()
# Out:
# book_table
# No     140
# Yes      8
# Name: count, dtype: int64

# %%
df.groupby("online_order")["votes"].mean()
# Out:
# online_order
# No      75.222222
# Yes    559.000000
# Name: votes, dtype: float64

# %%
df.columns.tolist()
# Out:
# ['name',
#  'online_order',
#  'book_table',
#  'rate',
#  'votes',
#  'approx_cost(for two people)',
#  'listed_in(type)']

# %%
df.groupby("book_table")["votes"].mean()
# Out:
# book_table
# No     226.185714
# Yes    940.750000
# Name: votes, dtype: float64

# %%
df.groupby("listed_in(type)")["votes"].mean()
# Out:
# listed_in(type)
# Buffet     432.571429
# Cafes      279.739130
# Dining     185.118182
# other     1170.875000
# Name: votes, dtype: float64

# %%
df["rate"].value_counts().head(10)
# Out:
# rate
# 3.8/5    19
# 3.7/5    15
# 3.3/5    14
# 3.4/5    12
# 4.1/5    11
# 3.6/5    11
# 4.0/5    10
# 3.9/5    10
# 4.2/5     8
# 3.1/5     7
# Name: count, dtype: int64

# %%
df.groupby("rate")["votes"].mean().head(10)
# Out:
# rate
# 2.6/5    283.000000
# 2.8/5    298.500000
# 2.9/5     15.571429
# 3.0/5     80.000000
# 3.1/5     46.142857
# 3.2/5     16.428571
# 3.3/5      8.642857
# 3.4/5      1.333333
# 3.5/5     21.166667
# 3.6/5     84.272727
# Name: votes, dtype: float64

# %%
df.groupby("listed_in(type)")["approx_cost(for two people)"].mean()
# Out:
# listed_in(type)
# Buffet    671.428571
# Cafes     545.652174
# Dining    357.272727
# other     668.750000
# Name: approx_cost(for two people), dtype: float64

# %%
df["listed_in(type)"].value_counts()
# Out:
# listed_in(type)
# Dining    110
# Cafes      23
# other       8
# Buffet      7
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# 25%       6.750000                   200.000000
# 50%      43.500000                   400.000000
# 75%     221.750000                   600.000000
# max    4884.000000                   950.000000

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
print(df.shape)
# Out:
# (148, 7)

# %%
df["name"].value_counts().head(10)
# Out:
# name
# San Churro Cafe               2
# CAFE NOVA                     2
# Onesta                        2
# Jalsa                         1
# Kotian Karavali Restaurant    1
# Kaggis                        1
# Ayda Persian Kitchen          1
# Chatar Patar                  1
# Polar Bear                    1
# Kidambi's Kitchen             1
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#                                               name online_order book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# 5                                  Timepass Dinner          Yes         No
# 6  Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                           Onesta          Yes        Yes
# 8                                   Penthouse Cafe          Yes         No
# 9                                        Smacznego          Yes         No
#
#     rate  votes  approx_cost(for two people) listed_in(type)
# 0  4.1/5    775                          800          Buffet
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["online_order"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='online_order'>

# %%
df["book_table"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='book_table'>

# %%
df["listed_in(type)"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='listed_in(type)'>

# %%
df["votes"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.groupby("online_order")["rate"].count()
# Out:
# online_order
# No     90
# Yes    58
# Name: rate, dtype: int64

# %%
df.groupby("book_table")["rate"].count()
# Out:
# book_table
# No     140
# Yes      8
# Name: rate, dtype: int64

# %%
df.groupby("listed_in(type)")["rate"].count()
# Out:
# listed_in(type)
# Buffet      7
# Cafes      23
# Dining    110
# other       8
# Name: rate, dtype: int64

# %%
df.describe()
# Out:
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# 25%       6.750000                   200.000000
# 50%      43.500000                   400.000000
# 75%     221.750000                   600.000000
# max    4884.000000                   950.000000

# %%
df.to_csv("Zomato_cleaned.csv", index=False)

# %%
print("Zomato Data Analysis Completed Successfully")
# Out:
# Zomato Data Analysis Completed Successfully
